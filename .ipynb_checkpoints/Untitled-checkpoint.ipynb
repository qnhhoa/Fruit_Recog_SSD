# %%
# Clone the tensorflow models repository from GitHub
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Cloning into 'models'...
# remote: Enumerating objects: 3909, done.
# remote: Counting objects: 100% (3909/3909), done.
# remote: Compressing objects: 100% (3015/3015), done.
# remote: Total 3909 (delta 1130), reused 2005 (delta 841), pack-reused 0
# Receiving objects: 100% (3909/3909), 49.65 MiB | 6.37 MiB/s, done.
# Resolving deltas: 100% (1130/1130), done.

# %%
# Copy setup files into models/research folder
# %cd /home/thuannd/SSD/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
#cp object_detection/packages/tf2/setup.py .
# Out:
# /home/thuannd/SSD/models/research
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# Modify setup.py file to install the tf-models-official repository targeted at TF v2.8.0
import re
with open('/home/thuannd/SSD/models/research/object_detection/packages/tf2/setup.py') as f:
    s = f.read()

with open('/home/thuannd/SSD/models/research/setup.py', 'w') as f:
    # Set fine_tune_checkpoint path
    s = re.sub('tf-models-official>=2.5.1',
               'tf-models-official==2.8.0', s)
    f.write(s)

# %%
# Install the Object Detection API
# !pip install /home/thuannd/SSD/models/research/

# Need to downgrade to TF v2.8.0 due to Colab compatibility bug with TF v2.10 (as of 10/03/22)
# !pip install tensorflow==2.8.0
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Processing /home/thuannd/SSD/models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: avro-python3 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (2.48.0)
# Requirement already satisfied: pillow in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (9.5.0)
# Requirement already satisfied: lxml in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (0.29.35)
# Requirement already satisfied: contextlib2 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (2.0.6)
# Requirement already satisfied: lvis in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: pandas in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (2.0.1)
# Requirement already satisfied: tf-models-official==2.8.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: tensorflow_io in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (0.32.0)
# Requirement already satisfied: keras in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: pyparsing==2.4.7 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.13.0)
# Requirement already satisfied: sentencepiece in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.1.99)
# Requirement already satisfied: seqeval in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.2.2)
# Requirement already satisfied: kaggle>=1.3.9 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.5.13)
# Requirement already satisfied: psutil>=5.4.3 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (5.9.5)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (5.4.1)
# Requirement already satisfied: opencv-python-headless in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: numpy>=1.15.4 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.23.5)
# Requirement already satisfied: tensorflow-text~=2.8.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.8.2)
# Requirement already satisfied: tensorflow~=2.8.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.8.4)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.89.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.7.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (9.0.0)
# Requirement already satisfied: gin-config in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.5.0)
# Requirement already satisfied: oauth2client in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.1.3)
# Requirement already satisfied: tensorflow-addons in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.20.0)
# Requirement already satisfied: tensorflow-datasets in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.9.2)
# Requirement already satisfied: pytz>=2020.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: regex in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.6.3)
# Requirement already satisfied: colorama in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: portalocker in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.7.0)
# Requirement already satisfied: tabulate>=0.8.9 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: absl-py>=0.2.2 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: orjson<4.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (3.9.1)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: cloudpickle~=2.2.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (11.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Collecting protobuf<4.24.0,>=3.20.3
#   Using cached protobuf-4.23.3-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.54.2)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.7.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.18)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.3.3)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.19.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.6.2)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.6.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.7.4)
# Requirement already satisfied: kiwisolver>=1.1.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: cycler>=0.10.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (4.39.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (2.11.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (4.1.1)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (2.19.0)
# Requirement already satisfied: docopt in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->object-detection==0.1) (3.15.0)
# Requirement already satisfied: certifi in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (2023.5.7)
# Requirement already satisfied: urllib3 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (1.26.16)
# Requirement already satisfied: python-slugify in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (8.0.1)
# Requirement already satisfied: tqdm in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (4.65.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.1.0)
# Requirement already satisfied: flatbuffers>=1.12 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.8.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (16.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.8.0)
# Collecting tensorflow~=2.8.0
#   Using cached tensorflow-2.8.3-cp39-cp39-manylinux2010_x86_64.whl (498.5 MB)
#   Using cached tensorflow-2.8.2-cp39-cp39-manylinux2010_x86_64.whl (498.0 MB)
#   Using cached tensorflow-2.8.1-cp39-cp39-manylinux2010_x86_64.whl (498.0 MB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (66.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.6.3)
# Requirement already satisfied: gast>=0.2.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.3.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official==2.8.0->object-detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (4.9)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (0.5.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from seqeval->tf-models-official==2.8.0->object-detection==0.1) (1.2.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-addons->tf-models-official==2.8.0->object-detection==0.1) (2.13.3)
# Requirement already satisfied: promise in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (2.3)
# Requirement already satisfied: click in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (8.1.3)
# Requirement already satisfied: tensorflow-metadata in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (1.13.1)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (1.3.0)
# Requirement already satisfied: toml in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (0.10.2)
# Requirement already satisfied: array-record in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.40.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (1.59.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (5.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object-detection==0.1) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object-detection==0.1) (1.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.4.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.6.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (6.6.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1655307 sha256=b55d7852451ebe733c60485ca9ca4b578a816cb83317bf934bb521cf88dfb431
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ctr2hgpl/wheels/fb/99/42/e47de2670f3b59c49699b17ba6a5abca5de56c34507ee7e68c
# Successfully built object-detection
# Installing collected packages: protobuf, tensorflow, object-detection
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.4
#     Uninstalling tensorflow-2.8.4:
#       Successfully uninstalled tensorflow-2.8.4

# %%
# Run Model Bulider Test file, just to verify everything's working properly
# !python /home/thuannd/SSD/models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Traceback (most recent call last):
#   File "/home/thuannd/SSD/models/research/object_detection/builders/model_builder_tf2_test.py", line 24, in <module>
#     from object_detection.builders import model_builder
#   File "/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/model_builder.py", line 23, in <module>
#     from object_detection.builders import anchor_generator_builder
#   File "/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/anchor_generator_builder.py", line 26, in <module>
#     from object_detection.protos import anchor_generator_pb2
#   File "/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/protos/anchor_generator_pb2.py", line 5, in <module>
#     from google.protobuf.internal import builder as _builder
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/google/protobuf/internal/__init__.py)

# %%
# !pip install protobuf --upgrade
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: protobuf in /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages (4.23.3)

# %%
# !conda install tensorflow==<3.20.1>
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !pip show protobuf
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Name: protobuf
# Version: 3.20.0
# Summary: Protocol Buffers
# Home-page: https://developers.google.com/protocol-buffers/
# Author:
# Author-email:
# License: BSD-3-Clause
# Location: /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages
# Requires:
# Required-by: apache-beam, dnn, google-api-core, googleapis-common-protos, onnxruntime, proto-plus, tensorboard, tensorflow, tensorflow-datasets, tensorflow-hub, tensorflow-metadata

# %%
# !pip install protobuf==3.20
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting protobuf==3.20
#   Downloading protobuf-3.20.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.3
#     Uninstalling protobuf-4.23.3:
#       Successfully uninstalled protobuf-4.23.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# googleapis-common-protos 1.59.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-api-core 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# apache-beam 2.48.0 requires protobuf<4.24.0,>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# Successfully installed protobuf-3.20.0

# %%
# !mkdir /home/thuannd/SSD/images
# !mkdir /home/thuannd/SSD/images/train; mkdir /home/thuannd/SSD/images/validation; mkdir /home/thuannd/SSD/images/test
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# %cd /home/thuannd/SSD/images/train
import glob
from pathlib import Path
import random
import os

# Define paths to image folders
image_path = '/home/thuannd/SSD/images/train'
train_path = '/home/thuannd/SSD/images/train'
val_path = '/home/thuannd/SSD/images/validation'
test_path = '/home/thuannd/SSD/images/test'

# Get list of all images
jpg_file_list = [path for path in Path(image_path).rglob('*.jpg')]
JPG_file_list = [path for path in Path(image_path).rglob('*.JPG')]
png_file_list = [path for path in Path(image_path).rglob('*.png')]
bmp_file_list = [path for path in Path(image_path).rglob('*.bmp')]

file_list = jpg_file_list + JPG_file_list + png_file_list + bmp_file_list
file_num = len(file_list)
print('Total images: %d' % file_num)

# Determine number of files to move to each folder
train_percent = 0.8  # 80% of the files go to train
val_percent = 0.1 # 10% go to validation
test_percent = 0.1 # 10% go to test
train_num = int(file_num*train_percent)
val_num = int(file_num*val_percent)
test_num = file_num - train_num - val_num
print('Images moving to train: %d' % train_num)
print('Images moving to validation: %d' % val_num)
print('Images moving to test: %d' % test_num)

# Select 80% of files randomly and move them to train folder
for i in range(train_num):
    move_me = random.choice(file_list)
    fn = move_me.name
    base_fn = move_me.stem
    parent_path = move_me.parent
    xml_fn = base_fn + '.xml'
    os.rename(move_me, train_path+'/'+fn)
    os.rename(os.path.join(parent_path,xml_fn),os.path.join(train_path,xml_fn))
    file_list.remove(move_me)

# Select 10% of remaining files and move them to validation folder
for i in range(val_num):
    move_me = random.choice(file_list)
    fn = move_me.name
    base_fn = move_me.stem
    parent_path = move_me.parent
    xml_fn = base_fn + '.xml'
    os.rename(move_me, val_path+'/'+fn)
    os.rename(os.path.join(parent_path,xml_fn),os.path.join(val_path,xml_fn))
    file_list.remove(move_me)

# Move remaining files to test folder
for i in range(test_num):
    move_me = random.choice(file_list)
    fn = move_me.name
    base_fn = move_me.stem
    parent_path = move_me.parent
    xml_fn = base_fn + '.xml'
    os.rename(move_me, test_path+'/'+fn)
    os.rename(os.path.join(parent_path,xml_fn),os.path.join(test_path,xml_fn))
    file_list.remove(move_me)
# Out:
# /home/thuannd/SSD/images/train
# Total images: 200
# Images moving to train: 160
# Images moving to validation: 20
# Images moving to test: 20

# %%
# %cd /home/thuannd/SSD
content = "AppleFresh"

with open("/home/thuannd/SSD/labelmap.txt", "w") as file:
    file.write(content)
# Out:
# /home/thuannd/SSD

# %%
# %cd /home/thuannd/SSD
# Download data conversion scripts
! wget https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/create_csv.py
! wget https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/create_tfrecord.py
# Out:
# /home/thuannd/SSD
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2023-06-20 00:09:22--  https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/create_csv.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348 (1,3K) [text/plain]
# Saving to: ‘create_csv.py’
#
# create_csv.py       100%[===================>]   1,32K  --.-KB/s    in 0s
#
# 2023-06-20 00:09:23 (70,9 MB/s) - ‘create_csv.py’ saved [1348/1348]
#
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2023-06-20 00:09:23--  https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/create_tfrecord.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4414 (4,3K) [text/plain]
# Saving to: ‘create_tfrecord.py’
#
# create_tfrecord.py  100%[===================>]   4,31K  --.-KB/s    in 0s
#
# 2023-06-20 00:09:24 (51,9 MB/s) - ‘create_tfrecord.py’ saved [4414/4414]

# %%
# Create CSV data files and TFRecord files
# %cd /home/thuannd/SSD
# !python3 create_csv.py
# !python3 create_tfrecord.py --csv_input=images/train_labels.csv --labelmap=labelmap.txt --image_dir=images/train --output_path=train.tfrecord
# Out:
# /home/thuannd/SSD
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Traceback (most recent call last):
#   File "/home/thuannd/SSD/create_csv.py", line 36, in <module>
#     main()
#   File "/home/thuannd/SSD/create_csv.py", line 32, in main
#     xml_df = xml_to_csv(image_path)
#   File "/home/thuannd/SSD/create_csv.py", line 19, in xml_to_csv
#     int(member[4][0].text),
# IndexError: child index out of range
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Successfully created the TFRecords: /home/thuannd/SSD/train.tfrecord

# %%
train_record_fname = '/home/thuannd/SSD/train.tfrecord'

label_map_pbtxt_fname = '/home/thuannd/SSD/labelmap.pbtxt'

# %%
# Change the chosen_model variable to deploy different models available in the TF2 object detection zoo
chosen_model = 'ssd-mobilenet-v2-fpnlite-320'

MODELS_CONFIG = {
    'ssd-mobilenet-v2': {
        'model_name': 'ssd_mobilenet_v2_320x320_coco17_tpu-8',
        'base_pipeline_file': 'ssd_mobilenet_v2_320x320_coco17_tpu-8.config',
        'pretrained_checkpoint': 'ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz',
    },
    'efficientdet-d0': {
        'model_name': 'efficientdet_d0_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d0_512x512_coco17_tpu-8.config',
        'pretrained_checkpoint': 'efficientdet_d0_coco17_tpu-32.tar.gz',
    },
    'ssd-mobilenet-v2-fpnlite-320': {
        'model_name': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8',
        'base_pipeline_file': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config',
        'pretrained_checkpoint': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz',
    },
    # The centernet model isn't working as of 9/10/22
    #'centernet-mobilenet-v2': {
    #    'model_name': 'centernet_mobilenetv2fpn_512x512_coco17_od',
    #    'base_pipeline_file': 'pipeline.config',
    #    'pretrained_checkpoint': 'centernet_mobilenetv2fpn_512x512_coco17_od.tar.gz',
    #}
}

model_name = MODELS_CONFIG[chosen_model]['model_name']
pretrained_checkpoint = MODELS_CONFIG[chosen_model]['pretrained_checkpoint']
base_pipeline_file = MODELS_CONFIG[chosen_model]['base_pipeline_file']

# %%
# Create "mymodel" folder for holding pre-trained weights and configuration files
# %mkdir /home/thuannd/SSD/models/mymodel/
# %cd /home/thuannd/SSD/models/mymodel/

# Download pre-trained model weights
import tarfile
download_tar = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/' + pretrained_checkpoint
# !wget {download_tar}
tar = tarfile.open(pretrained_checkpoint)
tar.extractall()
tar.close()

# Download training configuration file for model
download_config = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/' + base_pipeline_file
# !wget {download_config}
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /home/thuannd/SSD/models/mymodel
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2023-06-20 00:48:30--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.220.48, 2404:6800:4005:80d::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.220.48|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19,56M  11,6MB/s    in 1,7s
#
# 2023-06-20 00:48:32 (11,6 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2023-06-20 00:48:33--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4684 (4,6K) [text/plain]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config’
#
# ssd_mobilenet_v2_fp 100%[===================>]   4,57K  --.-KB/s    in 0s
#
# 2023-06-20 00:48:34 (58,1 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config’ saved [4684/4684]

# %%
# Set training parameters for the model
num_steps = 10000

if chosen_model == 'efficientdet-d0':
  batch_size = 4
else:
  batch_size = 16

# %%
# Set file locations and get number of classes for config file
pipeline_fname = '/home/thuannd/SSD/models/mymodel/' + base_pipeline_file
fine_tune_checkpoint = '/home/thuannd/SSD/models/mymodel/' + model_name + '/checkpoint/ckpt-0'

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())
num_classes = get_num_classes(label_map_pbtxt_fname)
print('Total classes:', num_classes)
# Out:
# Total classes: 4

# %%
# Create custom configuration file by writing the dataset, model checkpoint, and training parameters into the base pipeline file
import re

# %cd /home/thuannd/SSD/models/mymodel
print('writing custom configuration file')

with open(pipeline_fname) as f:
    s = f.read()
with open('pipeline_file.config', 'w') as f:
    
    # Set fine_tune_checkpoint path
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # Set tfrecord files for train and test datasets
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
  #  s = re.sub(
   #     '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 'input_path: "{}"'.format(val_record_fname), s)

    # Set label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set batch_size
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)

    # Change fine-tune checkpoint type from "classification" to "detection"
    s = re.sub(
        'fine_tune_checkpoint_type: "classification"', 'fine_tune_checkpoint_type: "{}"'.format('detection'), s)
    
    # If using ssd-mobilenet-v2, reduce learning rate (because it's too high in the default config file)
    if chosen_model == 'ssd-mobilenet-v2':
      s = re.sub('learning_rate_base: .8',
                 'learning_rate_base: .08', s)
      
      s = re.sub('warmup_learning_rate: 0.13333',
                 'warmup_learning_rate: .026666', s)
    
    # If using efficientdet-d0, use fixed_shape_resizer instead of keep_aspect_ratio_resizer (because it isn't supported by TFLite)
    if chosen_model == 'efficientdet-d0':
      s = re.sub('keep_aspect_ratio_resizer', 'fixed_shape_resizer', s)
      s = re.sub('pad_to_max_dimension: true', '', s)
      s = re.sub('min_dimension', 'height', s)
      s = re.sub('max_dimension', 'width', s)

    f.write(s)
# Out:
# /home/thuannd/SSD/models/mymodel
# writing custom configuration file

# %%
# (Optional) Display the custom configuration file's contents
# !cat /home/thuannd/SSD/models/mymodel/pipeline_file.config
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# # SSD with Mobilenet v2 FPN-lite (go/fpn-lite) feature extractor, shared box
# # predictor and focal loss (a mobile version of Retinanet).
# # Retinanet: see Lin et al, https://arxiv.org/abs/1708.02002
# # Trained on COCO, initialized from Imagenet classification checkpoint
# # Train on TPU-8
# #
# # Achieves 22.2 mAP on COCO17 Val
#
# model {
#   ssd {
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#     num_classes: 4
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     encode_background_as_zeros: true
#     anchor_generator {
#       multiscale_anchor_generator {
#         min_level: 3
#         max_level: 7
#         anchor_scale: 4.0
#         aspect_ratios: [1.0, 2.0, 0.5]
#         scales_per_octave: 2
#       }
#     }
#     image_resizer {
#       fixed_shape_resizer {
#         height: 320
#         width: 320
#       }
#     }
#     box_predictor {
#       weight_shared_convolutional_box_predictor {
#         depth: 128
#         class_prediction_bias_init: -4.6
#         conv_hyperparams {
#           activation: RELU_6,
#           regularizer {
#             l2_regularizer {
#               weight: 0.00004
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               stddev: 0.01
#               mean: 0.0
#             }
#           }
#           batch_norm {
#             scale: true,
#             decay: 0.997,
#             epsilon: 0.001,
#           }
#         }
#         num_layers_before_predictor: 4
#         share_prediction_tower: true
#         use_depthwise: true
#         kernel_size: 3
#       }
#     }
#     feature_extractor {
#       type: 'ssd_mobilenet_v2_fpn_keras'
#       use_depthwise: true
#       fpn {
#         min_level: 3
#         max_level: 7
#         additional_layer_depth: 128
#       }
#       min_depth: 16
#       depth_multiplier: 1.0
#       conv_hyperparams {
#         activation: RELU_6,
#         regularizer {
#           l2_regularizer {
#             weight: 0.00004
#           }
#         }
#         initializer {
#           random_normal_initializer {
#             stddev: 0.01
#             mean: 0.0
#           }
#         }
#         batch_norm {
#           scale: true,
#           decay: 0.997,
#           epsilon: 0.001,
#         }
#       }
#       override_base_feature_extractor_hyperparams: true
#     }
#     loss {
#       classification_loss {
#         weighted_sigmoid_focal {
#           alpha: 0.25
#           gamma: 2.0
#         }
#       }
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     normalize_loss_by_num_matches: true
#     normalize_loc_loss_by_codesize: true
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-8
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#   }
# }
#
# train_config: {
#   fine_tune_checkpoint_version: V2
#   fine_tune_checkpoint: "/home/thuannd/SSD/models/mymodel/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0"
#   fine_tune_checkpoint_type: "detection"
#   batch_size: 16
#   sync_replicas: true
#   startup_delay_steps: 0
#   replicas_to_aggregate: 8
#   num_steps: 10000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     random_crop_image {
#       min_object_covered: 0.0
#       min_aspect_ratio: 0.75
#       max_aspect_ratio: 3.0
#       min_area: 0.75
#       max_area: 1.0
#       overlap_thresh: 0.0
#     }
#   }
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         cosine_decay_learning_rate {
#           learning_rate_base: .08
#           total_steps: 50000
#           warmup_learning_rate: .026666
#           warmup_steps: 1000
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
# }
#
# train_input_reader: {
#   label_map_path: "/home/thuannd/SSD/labelmap.pbtxt"
#   tf_record_input_reader {
#     input_path: "/home/thuannd/SSD/train.tfrecord"
#   }
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
# }
#
# eval_input_reader: {
#   label_map_path: "/home/thuannd/SSD/labelmap.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#   }
# }

# %%
# Set the path to the custom config file and the directory to store training checkpoints in
pipeline_file = '/home/thuannd/SSD/models/mymodel/pipeline_file.config'
model_dir = '/home/thuannd/SSD/training/'

# %%
# %load_ext tensorboard
# %tensorboard --logdir '/home/thuannd/SSD/training/train'
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 3554054), started 2:26:32 ago. (Use '!kill 3554054' to kill it.)
#       <iframe id="tensorboard-frame-6033404579d29de" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6033404579d29de");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Run training!
# !python /home/thuannd/SSD/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_file} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --sample_1_of_n_eval_examples=1
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.10.0 and strictly below 2.13.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0620 00:59:43.484157 140135427274560 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I0620 00:59:43.488008 140135427274560 config_util.py:552] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0620 00:59:43.488115 140135427274560 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0620 00:59:43.511502 140135427274560 deprecation.py:337] From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/home/thuannd/SSD/train.tfrecord']
# I0620 00:59:43.514851 140135427274560 dataset_builder.py:162] Reading unweighted datasets: ['/home/thuannd/SSD/train.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/thuannd/SSD/train.tfrecord']
# I0620 00:59:43.514986 140135427274560 dataset_builder.py:79] Reading record datasets for input file: ['/home/thuannd/SSD/train.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0620 00:59:43.515072 140135427274560 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0620 00:59:43.515130 140135427274560 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0620 00:59:43.517230 140135427274560 deprecation.py:337] From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0620 00:59:43.538490 140135427274560 deprecation.py:337] From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0620 00:59:50.220366 140135427274560 deprecation.py:337] From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0620 00:59:52.934331 140135427274560 deprecation.py:337] From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0620 00:59:54.489558 140135427274560 deprecation.py:337] From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0620 01:00:02.963216 140097102001728 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0620 01:00:14.672327 140097102001728 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-20 01:00:24.774995: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-06-20 01:00:24.776384: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.864810 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.866166 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.868042 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.868873 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.870736 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.871567 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.873774 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.874642 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.876527 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0620 01:00:27.877358 140135427274560 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0620 01:00:28.463761 140096286217792 deprecation.py:541] From /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0620 01:00:29.291173 140096286217792 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0620 01:00:37.894782 140096286217792 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0620 01:00:46.051893 140096286217792 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0620 01:00:54.302823 140096286217792 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.646s
# I0620 01:01:32.851606 140135427274560 model_lib_v2.py:705] Step 100 per-step time 0.646s
# INFO:tensorflow:{'Loss/classification_loss': 0.14103106,
#  'Loss/localization_loss': 0.0982857,
#  'Loss/regularization_loss': 0.15330961,
#  'Loss/total_loss': 0.39262637,
#  'learning_rate': 0.0319994}
# I0620 01:01:32.852501 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.14103106,
#  'Loss/localization_loss': 0.0982857,
#  'Loss/regularization_loss': 0.15330961,
#  'Loss/total_loss': 0.39262637,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.190s
# I0620 01:01:51.621691 140135427274560 model_lib_v2.py:705] Step 200 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.11788288,
#  'Loss/localization_loss': 0.05551626,
#  'Loss/regularization_loss': 0.15298204,
#  'Loss/total_loss': 0.32638118,
#  'learning_rate': 0.0373328}
# I0620 01:01:51.622639 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.11788288,
#  'Loss/localization_loss': 0.05551626,
#  'Loss/regularization_loss': 0.15298204,
#  'Loss/total_loss': 0.32638118,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.189s
# I0620 01:02:10.493448 140135427274560 model_lib_v2.py:705] Step 300 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.09778655,
#  'Loss/localization_loss': 0.04106975,
#  'Loss/regularization_loss': 0.1525756,
#  'Loss/total_loss': 0.2914319,
#  'learning_rate': 0.0426662}
# I0620 01:02:10.494180 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.09778655,
#  'Loss/localization_loss': 0.04106975,
#  'Loss/regularization_loss': 0.1525756,
#  'Loss/total_loss': 0.2914319,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.188s
# I0620 01:02:29.240304 140135427274560 model_lib_v2.py:705] Step 400 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.09395001,
#  'Loss/localization_loss': 0.049710773,
#  'Loss/regularization_loss': 0.15211639,
#  'Loss/total_loss': 0.29577717,
#  'learning_rate': 0.047999598}
# I0620 01:02:29.241234 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.09395001,
#  'Loss/localization_loss': 0.049710773,
#  'Loss/regularization_loss': 0.15211639,
#  'Loss/total_loss': 0.29577717,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.188s
# I0620 01:02:48.003008 140135427274560 model_lib_v2.py:705] Step 500 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.07214058,
#  'Loss/localization_loss': 0.027435722,
#  'Loss/regularization_loss': 0.15159762,
#  'Loss/total_loss': 0.2511739,
#  'learning_rate': 0.053333}
# I0620 01:02:48.004328 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.07214058,
#  'Loss/localization_loss': 0.027435722,
#  'Loss/regularization_loss': 0.15159762,
#  'Loss/total_loss': 0.2511739,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.188s
# I0620 01:03:06.846332 140135427274560 model_lib_v2.py:705] Step 600 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.07711952,
#  'Loss/localization_loss': 0.045881726,
#  'Loss/regularization_loss': 0.15102275,
#  'Loss/total_loss': 0.274024,
#  'learning_rate': 0.0586664}
# I0620 01:03:06.846899 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.07711952,
#  'Loss/localization_loss': 0.045881726,
#  'Loss/regularization_loss': 0.15102275,
#  'Loss/total_loss': 0.274024,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.190s
# I0620 01:03:25.805912 140135427274560 model_lib_v2.py:705] Step 700 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.0721645,
#  'Loss/localization_loss': 0.037906636,
#  'Loss/regularization_loss': 0.15039675,
#  'Loss/total_loss': 0.2604679,
#  'learning_rate': 0.0639998}
# I0620 01:03:25.807406 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.0721645,
#  'Loss/localization_loss': 0.037906636,
#  'Loss/regularization_loss': 0.15039675,
#  'Loss/total_loss': 0.2604679,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.189s
# I0620 01:03:44.658149 140135427274560 model_lib_v2.py:705] Step 800 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.07174373,
#  'Loss/localization_loss': 0.02487727,
#  'Loss/regularization_loss': 0.14971521,
#  'Loss/total_loss': 0.24633622,
#  'learning_rate': 0.069333196}
# I0620 01:03:44.658691 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.07174373,
#  'Loss/localization_loss': 0.02487727,
#  'Loss/regularization_loss': 0.14971521,
#  'Loss/total_loss': 0.24633622,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.188s
# I0620 01:04:03.490680 140135427274560 model_lib_v2.py:705] Step 900 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.066480815,
#  'Loss/localization_loss': 0.053359978,
#  'Loss/regularization_loss': 0.14897646,
#  'Loss/total_loss': 0.26881725,
#  'learning_rate': 0.074666604}
# I0620 01:04:03.491844 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.066480815,
#  'Loss/localization_loss': 0.053359978,
#  'Loss/regularization_loss': 0.14897646,
#  'Loss/total_loss': 0.26881725,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.186s
# I0620 01:04:22.112941 140135427274560 model_lib_v2.py:705] Step 1000 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.058730565,
#  'Loss/localization_loss': 0.022064818,
#  'Loss/regularization_loss': 0.14819415,
#  'Loss/total_loss': 0.22898954,
#  'learning_rate': 0.08}
# I0620 01:04:22.113773 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.058730565,
#  'Loss/localization_loss': 0.022064818,
#  'Loss/regularization_loss': 0.14819415,
#  'Loss/total_loss': 0.22898954,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.193s
# I0620 01:04:41.439615 140135427274560 model_lib_v2.py:705] Step 1100 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.058523916,
#  'Loss/localization_loss': 0.019335983,
#  'Loss/regularization_loss': 0.14736362,
#  'Loss/total_loss': 0.22522351,
#  'learning_rate': 0.07999918}
# I0620 01:04:41.440217 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.058523916,
#  'Loss/localization_loss': 0.019335983,
#  'Loss/regularization_loss': 0.14736362,
#  'Loss/total_loss': 0.22522351,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.189s
# I0620 01:05:00.387279 140135427274560 model_lib_v2.py:705] Step 1200 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.071981475,
#  'Loss/localization_loss': 0.030215237,
#  'Loss/regularization_loss': 0.14654759,
#  'Loss/total_loss': 0.2487443,
#  'learning_rate': 0.079996705}
# I0620 01:05:00.387750 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.071981475,
#  'Loss/localization_loss': 0.030215237,
#  'Loss/regularization_loss': 0.14654759,
#  'Loss/total_loss': 0.2487443,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.190s
# I0620 01:05:19.347724 140135427274560 model_lib_v2.py:705] Step 1300 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.06310954,
#  'Loss/localization_loss': 0.022610266,
#  'Loss/regularization_loss': 0.14571947,
#  'Loss/total_loss': 0.23143928,
#  'learning_rate': 0.0799926}
# I0620 01:05:19.348317 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.06310954,
#  'Loss/localization_loss': 0.022610266,
#  'Loss/regularization_loss': 0.14571947,
#  'Loss/total_loss': 0.23143928,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.187s
# I0620 01:05:38.052823 140135427274560 model_lib_v2.py:705] Step 1400 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.05133595,
#  'Loss/localization_loss': 0.018139448,
#  'Loss/regularization_loss': 0.14498287,
#  'Loss/total_loss': 0.21445827,
#  'learning_rate': 0.07998685}
# I0620 01:05:38.053975 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.05133595,
#  'Loss/localization_loss': 0.018139448,
#  'Loss/regularization_loss': 0.14498287,
#  'Loss/total_loss': 0.21445827,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.187s
# I0620 01:05:56.772904 140135427274560 model_lib_v2.py:705] Step 1500 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.050659526,
#  'Loss/localization_loss': 0.014192809,
#  'Loss/regularization_loss': 0.14415824,
#  'Loss/total_loss': 0.20901057,
#  'learning_rate': 0.07997945}
# I0620 01:05:56.773746 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.050659526,
#  'Loss/localization_loss': 0.014192809,
#  'Loss/regularization_loss': 0.14415824,
#  'Loss/total_loss': 0.20901057,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.187s
# I0620 01:06:15.516620 140135427274560 model_lib_v2.py:705] Step 1600 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.055634,
#  'Loss/localization_loss': 0.0146784745,
#  'Loss/regularization_loss': 0.14333044,
#  'Loss/total_loss': 0.21364291,
#  'learning_rate': 0.079970405}
# I0620 01:06:15.517190 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.055634,
#  'Loss/localization_loss': 0.0146784745,
#  'Loss/regularization_loss': 0.14333044,
#  'Loss/total_loss': 0.21364291,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.188s
# I0620 01:06:34.317476 140135427274560 model_lib_v2.py:705] Step 1700 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.05057238,
#  'Loss/localization_loss': 0.017932627,
#  'Loss/regularization_loss': 0.14250556,
#  'Loss/total_loss': 0.21101056,
#  'learning_rate': 0.07995972}
# I0620 01:06:34.318041 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.05057238,
#  'Loss/localization_loss': 0.017932627,
#  'Loss/regularization_loss': 0.14250556,
#  'Loss/total_loss': 0.21101056,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.188s
# I0620 01:06:53.112467 140135427274560 model_lib_v2.py:705] Step 1800 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.052393466,
#  'Loss/localization_loss': 0.018426202,
#  'Loss/regularization_loss': 0.14168257,
#  'Loss/total_loss': 0.21250224,
#  'learning_rate': 0.0799474}
# I0620 01:06:53.113038 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.052393466,
#  'Loss/localization_loss': 0.018426202,
#  'Loss/regularization_loss': 0.14168257,
#  'Loss/total_loss': 0.21250224,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.190s
# I0620 01:07:12.116530 140135427274560 model_lib_v2.py:705] Step 1900 per-step time 0.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.06442058,
#  'Loss/localization_loss': 0.019899916,
#  'Loss/regularization_loss': 0.1408697,
#  'Loss/total_loss': 0.2251902,
#  'learning_rate': 0.07993342}
# I0620 01:07:12.117094 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.06442058,
#  'Loss/localization_loss': 0.019899916,
#  'Loss/regularization_loss': 0.1408697,
#  'Loss/total_loss': 0.2251902,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.189s
# I0620 01:07:31.013465 140135427274560 model_lib_v2.py:705] Step 2000 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.054183565,
#  'Loss/localization_loss': 0.01338901,
#  'Loss/regularization_loss': 0.1400603,
#  'Loss/total_loss': 0.20763288,
#  'learning_rate': 0.07991781}
# I0620 01:07:31.014608 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.054183565,
#  'Loss/localization_loss': 0.01338901,
#  'Loss/regularization_loss': 0.1400603,
#  'Loss/total_loss': 0.20763288,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.194s
# I0620 01:07:50.413459 140135427274560 model_lib_v2.py:705] Step 2100 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.05064259,
#  'Loss/localization_loss': 0.018757517,
#  'Loss/regularization_loss': 0.13925028,
#  'Loss/total_loss': 0.20865038,
#  'learning_rate': 0.07990056}
# I0620 01:07:50.414160 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.05064259,
#  'Loss/localization_loss': 0.018757517,
#  'Loss/regularization_loss': 0.13925028,
#  'Loss/total_loss': 0.20865038,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.187s
# I0620 01:08:09.161841 140135427274560 model_lib_v2.py:705] Step 2200 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.05595278,
#  'Loss/localization_loss': 0.016253661,
#  'Loss/regularization_loss': 0.13845822,
#  'Loss/total_loss': 0.21066466,
#  'learning_rate': 0.07988167}
# I0620 01:08:09.162531 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.05595278,
#  'Loss/localization_loss': 0.016253661,
#  'Loss/regularization_loss': 0.13845822,
#  'Loss/total_loss': 0.21066466,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.186s
# I0620 01:08:27.793540 140135427274560 model_lib_v2.py:705] Step 2300 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.047404036,
#  'Loss/localization_loss': 0.020641286,
#  'Loss/regularization_loss': 0.13766305,
#  'Loss/total_loss': 0.20570837,
#  'learning_rate': 0.07986114}
# I0620 01:08:27.794103 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.047404036,
#  'Loss/localization_loss': 0.020641286,
#  'Loss/regularization_loss': 0.13766305,
#  'Loss/total_loss': 0.20570837,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.187s
# I0620 01:08:46.455931 140135427274560 model_lib_v2.py:705] Step 2400 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.046244718,
#  'Loss/localization_loss': 0.014655181,
#  'Loss/regularization_loss': 0.1368684,
#  'Loss/total_loss': 0.1977683,
#  'learning_rate': 0.07983897}
# I0620 01:08:46.456527 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.046244718,
#  'Loss/localization_loss': 0.014655181,
#  'Loss/regularization_loss': 0.1368684,
#  'Loss/total_loss': 0.1977683,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.189s
# I0620 01:09:05.395482 140135427274560 model_lib_v2.py:705] Step 2500 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.049529728,
#  'Loss/localization_loss': 0.010792759,
#  'Loss/regularization_loss': 0.13607658,
#  'Loss/total_loss': 0.19639906,
#  'learning_rate': 0.079815164}
# I0620 01:09:05.396023 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.049529728,
#  'Loss/localization_loss': 0.010792759,
#  'Loss/regularization_loss': 0.13607658,
#  'Loss/total_loss': 0.19639906,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.189s
# I0620 01:09:24.345713 140135427274560 model_lib_v2.py:705] Step 2600 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.047216024,
#  'Loss/localization_loss': 0.013827297,
#  'Loss/regularization_loss': 0.13531846,
#  'Loss/total_loss': 0.19636178,
#  'learning_rate': 0.07978972}
# I0620 01:09:24.346277 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.047216024,
#  'Loss/localization_loss': 0.013827297,
#  'Loss/regularization_loss': 0.13531846,
#  'Loss/total_loss': 0.19636178,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.187s
# I0620 01:09:43.031661 140135427274560 model_lib_v2.py:705] Step 2700 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.051395718,
#  'Loss/localization_loss': 0.013996845,
#  'Loss/regularization_loss': 0.13455008,
#  'Loss/total_loss': 0.19994265,
#  'learning_rate': 0.07976264}
# I0620 01:09:43.032216 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.051395718,
#  'Loss/localization_loss': 0.013996845,
#  'Loss/regularization_loss': 0.13455008,
#  'Loss/total_loss': 0.19994265,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.186s
# I0620 01:10:01.657758 140135427274560 model_lib_v2.py:705] Step 2800 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.05199944,
#  'Loss/localization_loss': 0.012686412,
#  'Loss/regularization_loss': 0.13377735,
#  'Loss/total_loss': 0.1984632,
#  'learning_rate': 0.07973392}
# I0620 01:10:01.658373 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.05199944,
#  'Loss/localization_loss': 0.012686412,
#  'Loss/regularization_loss': 0.13377735,
#  'Loss/total_loss': 0.1984632,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.187s
# I0620 01:10:20.368612 140135427274560 model_lib_v2.py:705] Step 2900 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.052795965,
#  'Loss/localization_loss': 0.012755099,
#  'Loss/regularization_loss': 0.13300928,
#  'Loss/total_loss': 0.19856036,
#  'learning_rate': 0.07970358}
# I0620 01:10:20.369687 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.052795965,
#  'Loss/localization_loss': 0.012755099,
#  'Loss/regularization_loss': 0.13300928,
#  'Loss/total_loss': 0.19856036,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.189s
# I0620 01:10:39.239132 140135427274560 model_lib_v2.py:705] Step 3000 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.0416121,
#  'Loss/localization_loss': 0.013471337,
#  'Loss/regularization_loss': 0.13224424,
#  'Loss/total_loss': 0.18732768,
#  'learning_rate': 0.0796716}
# I0620 01:10:39.239670 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.0416121,
#  'Loss/localization_loss': 0.013471337,
#  'Loss/regularization_loss': 0.13224424,
#  'Loss/total_loss': 0.18732768,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.193s
# I0620 01:10:58.510108 140135427274560 model_lib_v2.py:705] Step 3100 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.05463545,
#  'Loss/localization_loss': 0.015029701,
#  'Loss/regularization_loss': 0.13150017,
#  'Loss/total_loss': 0.20116532,
#  'learning_rate': 0.07963799}
# I0620 01:10:58.510811 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.05463545,
#  'Loss/localization_loss': 0.015029701,
#  'Loss/regularization_loss': 0.13150017,
#  'Loss/total_loss': 0.20116532,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.186s
# I0620 01:11:17.102679 140135427274560 model_lib_v2.py:705] Step 3200 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.056981564,
#  'Loss/localization_loss': 0.014863945,
#  'Loss/regularization_loss': 0.13074322,
#  'Loss/total_loss': 0.20258874,
#  'learning_rate': 0.07960275}
# I0620 01:11:17.103226 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.056981564,
#  'Loss/localization_loss': 0.014863945,
#  'Loss/regularization_loss': 0.13074322,
#  'Loss/total_loss': 0.20258874,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.188s
# I0620 01:11:35.859487 140135427274560 model_lib_v2.py:705] Step 3300 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.046062335,
#  'Loss/localization_loss': 0.011731173,
#  'Loss/regularization_loss': 0.12999149,
#  'Loss/total_loss': 0.187785,
#  'learning_rate': 0.07956588}
# I0620 01:11:35.860065 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.046062335,
#  'Loss/localization_loss': 0.011731173,
#  'Loss/regularization_loss': 0.12999149,
#  'Loss/total_loss': 0.187785,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.188s
# I0620 01:11:54.667528 140135427274560 model_lib_v2.py:705] Step 3400 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.05016024,
#  'Loss/localization_loss': 0.012779018,
#  'Loss/regularization_loss': 0.12924536,
#  'Loss/total_loss': 0.19218461,
#  'learning_rate': 0.079527386}
# I0620 01:11:54.667932 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.05016024,
#  'Loss/localization_loss': 0.012779018,
#  'Loss/regularization_loss': 0.12924536,
#  'Loss/total_loss': 0.19218461,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.187s
# I0620 01:12:13.326214 140135427274560 model_lib_v2.py:705] Step 3500 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.045611043,
#  'Loss/localization_loss': 0.011073132,
#  'Loss/regularization_loss': 0.12850304,
#  'Loss/total_loss': 0.18518722,
#  'learning_rate': 0.07948727}
# I0620 01:12:13.326757 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.045611043,
#  'Loss/localization_loss': 0.011073132,
#  'Loss/regularization_loss': 0.12850304,
#  'Loss/total_loss': 0.18518722,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.188s
# I0620 01:12:32.133724 140135427274560 model_lib_v2.py:705] Step 3600 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.042255368,
#  'Loss/localization_loss': 0.017108265,
#  'Loss/regularization_loss': 0.12777013,
#  'Loss/total_loss': 0.18713376,
#  'learning_rate': 0.079445526}
# I0620 01:12:32.134351 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.042255368,
#  'Loss/localization_loss': 0.017108265,
#  'Loss/regularization_loss': 0.12777013,
#  'Loss/total_loss': 0.18713376,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.187s
# I0620 01:12:50.785852 140135427274560 model_lib_v2.py:705] Step 3700 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.047562294,
#  'Loss/localization_loss': 0.011963851,
#  'Loss/regularization_loss': 0.12703654,
#  'Loss/total_loss': 0.18656269,
#  'learning_rate': 0.07940216}
# I0620 01:12:50.786918 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.047562294,
#  'Loss/localization_loss': 0.011963851,
#  'Loss/regularization_loss': 0.12703654,
#  'Loss/total_loss': 0.18656269,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.187s
# I0620 01:13:09.468498 140135427274560 model_lib_v2.py:705] Step 3800 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.041739006,
#  'Loss/localization_loss': 0.0110956365,
#  'Loss/regularization_loss': 0.12630616,
#  'Loss/total_loss': 0.1791408,
#  'learning_rate': 0.079357184}
# I0620 01:13:09.469091 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.041739006,
#  'Loss/localization_loss': 0.0110956365,
#  'Loss/regularization_loss': 0.12630616,
#  'Loss/total_loss': 0.1791408,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.187s
# I0620 01:13:28.182931 140135427274560 model_lib_v2.py:705] Step 3900 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.051913876,
#  'Loss/localization_loss': 0.01289227,
#  'Loss/regularization_loss': 0.12558083,
#  'Loss/total_loss': 0.19038698,
#  'learning_rate': 0.07931058}
# I0620 01:13:28.183483 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.051913876,
#  'Loss/localization_loss': 0.01289227,
#  'Loss/regularization_loss': 0.12558083,
#  'Loss/total_loss': 0.19038698,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.188s
# I0620 01:13:46.954841 140135427274560 model_lib_v2.py:705] Step 4000 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.04258382,
#  'Loss/localization_loss': 0.013205159,
#  'Loss/regularization_loss': 0.12486242,
#  'Loss/total_loss': 0.1806514,
#  'learning_rate': 0.07926236}
# I0620 01:13:46.955402 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.04258382,
#  'Loss/localization_loss': 0.013205159,
#  'Loss/regularization_loss': 0.12486242,
#  'Loss/total_loss': 0.1806514,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.192s
# I0620 01:14:06.184146 140135427274560 model_lib_v2.py:705] Step 4100 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.04537564,
#  'Loss/localization_loss': 0.009266501,
#  'Loss/regularization_loss': 0.124151014,
#  'Loss/total_loss': 0.17879316,
#  'learning_rate': 0.07921253}
# I0620 01:14:06.184810 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.04537564,
#  'Loss/localization_loss': 0.009266501,
#  'Loss/regularization_loss': 0.124151014,
#  'Loss/total_loss': 0.17879316,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.186s
# I0620 01:14:24.791946 140135427274560 model_lib_v2.py:705] Step 4200 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.032362092,
#  'Loss/localization_loss': 0.0074846786,
#  'Loss/regularization_loss': 0.12344934,
#  'Loss/total_loss': 0.1632961,
#  'learning_rate': 0.07916109}
# I0620 01:14:24.792507 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.032362092,
#  'Loss/localization_loss': 0.0074846786,
#  'Loss/regularization_loss': 0.12344934,
#  'Loss/total_loss': 0.1632961,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.188s
# I0620 01:14:43.566242 140135427274560 model_lib_v2.py:705] Step 4300 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.03700295,
#  'Loss/localization_loss': 0.007128199,
#  'Loss/regularization_loss': 0.12274176,
#  'Loss/total_loss': 0.1668729,
#  'learning_rate': 0.07910804}
# I0620 01:14:43.566954 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03700295,
#  'Loss/localization_loss': 0.007128199,
#  'Loss/regularization_loss': 0.12274176,
#  'Loss/total_loss': 0.1668729,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.188s
# I0620 01:15:02.388906 140135427274560 model_lib_v2.py:705] Step 4400 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.040618032,
#  'Loss/localization_loss': 0.011074534,
#  'Loss/regularization_loss': 0.12204331,
#  'Loss/total_loss': 0.17373589,
#  'learning_rate': 0.07905338}
# I0620 01:15:02.390231 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.040618032,
#  'Loss/localization_loss': 0.011074534,
#  'Loss/regularization_loss': 0.12204331,
#  'Loss/total_loss': 0.17373589,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.187s
# I0620 01:15:21.113727 140135427274560 model_lib_v2.py:705] Step 4500 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.04114853,
#  'Loss/localization_loss': 0.00885544,
#  'Loss/regularization_loss': 0.121342555,
#  'Loss/total_loss': 0.17134652,
#  'learning_rate': 0.07899711}
# I0620 01:15:21.114444 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.04114853,
#  'Loss/localization_loss': 0.00885544,
#  'Loss/regularization_loss': 0.121342555,
#  'Loss/total_loss': 0.17134652,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.188s
# I0620 01:15:39.873762 140135427274560 model_lib_v2.py:705] Step 4600 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.03671315,
#  'Loss/localization_loss': 0.011095114,
#  'Loss/regularization_loss': 0.120652325,
#  'Loss/total_loss': 0.1684606,
#  'learning_rate': 0.078939244}
# I0620 01:15:39.874434 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03671315,
#  'Loss/localization_loss': 0.011095114,
#  'Loss/regularization_loss': 0.120652325,
#  'Loss/total_loss': 0.1684606,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.187s
# I0620 01:15:58.546539 140135427274560 model_lib_v2.py:705] Step 4700 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.042446367,
#  'Loss/localization_loss': 0.008412469,
#  'Loss/regularization_loss': 0.119968556,
#  'Loss/total_loss': 0.17082739,
#  'learning_rate': 0.07887978}
# I0620 01:15:58.547099 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.042446367,
#  'Loss/localization_loss': 0.008412469,
#  'Loss/regularization_loss': 0.119968556,
#  'Loss/total_loss': 0.17082739,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.186s
# I0620 01:16:17.134557 140135427274560 model_lib_v2.py:705] Step 4800 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.03611317,
#  'Loss/localization_loss': 0.009429885,
#  'Loss/regularization_loss': 0.119291775,
#  'Loss/total_loss': 0.16483483,
#  'learning_rate': 0.07881871}
# I0620 01:16:17.135093 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03611317,
#  'Loss/localization_loss': 0.009429885,
#  'Loss/regularization_loss': 0.119291775,
#  'Loss/total_loss': 0.16483483,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.188s
# I0620 01:16:35.940955 140135427274560 model_lib_v2.py:705] Step 4900 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.047461923,
#  'Loss/localization_loss': 0.009889015,
#  'Loss/regularization_loss': 0.11861934,
#  'Loss/total_loss': 0.17597027,
#  'learning_rate': 0.07875605}
# I0620 01:16:35.941516 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.047461923,
#  'Loss/localization_loss': 0.009889015,
#  'Loss/regularization_loss': 0.11861934,
#  'Loss/total_loss': 0.17597027,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.186s
# I0620 01:16:54.554049 140135427274560 model_lib_v2.py:705] Step 5000 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.036667544,
#  'Loss/localization_loss': 0.009155584,
#  'Loss/regularization_loss': 0.11794943,
#  'Loss/total_loss': 0.16377255,
#  'learning_rate': 0.078691795}
# I0620 01:16:54.554594 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.036667544,
#  'Loss/localization_loss': 0.009155584,
#  'Loss/regularization_loss': 0.11794943,
#  'Loss/total_loss': 0.16377255,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.193s
# I0620 01:17:13.828286 140135427274560 model_lib_v2.py:705] Step 5100 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.039069727,
#  'Loss/localization_loss': 0.009177496,
#  'Loss/regularization_loss': 0.11727844,
#  'Loss/total_loss': 0.16552566,
#  'learning_rate': 0.07862595}
# I0620 01:17:13.828974 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.039069727,
#  'Loss/localization_loss': 0.009177496,
#  'Loss/regularization_loss': 0.11727844,
#  'Loss/total_loss': 0.16552566,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.187s
# I0620 01:17:32.495081 140135427274560 model_lib_v2.py:705] Step 5200 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.04267407,
#  'Loss/localization_loss': 0.0088087255,
#  'Loss/regularization_loss': 0.11661181,
#  'Loss/total_loss': 0.1680946,
#  'learning_rate': 0.07855851}
# I0620 01:17:32.496101 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.04267407,
#  'Loss/localization_loss': 0.0088087255,
#  'Loss/regularization_loss': 0.11661181,
#  'Loss/total_loss': 0.1680946,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.185s
# I0620 01:17:50.953349 140135427274560 model_lib_v2.py:705] Step 5300 per-step time 0.185s
# INFO:tensorflow:{'Loss/classification_loss': 0.033259615,
#  'Loss/localization_loss': 0.008972644,
#  'Loss/regularization_loss': 0.11595034,
#  'Loss/total_loss': 0.15818259,
#  'learning_rate': 0.07848949}
# I0620 01:17:50.954055 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.033259615,
#  'Loss/localization_loss': 0.008972644,
#  'Loss/regularization_loss': 0.11595034,
#  'Loss/total_loss': 0.15818259,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.187s
# I0620 01:18:09.629094 140135427274560 model_lib_v2.py:705] Step 5400 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.035573997,
#  'Loss/localization_loss': 0.01327979,
#  'Loss/regularization_loss': 0.115305215,
#  'Loss/total_loss': 0.164159,
#  'learning_rate': 0.078418896}
# I0620 01:18:09.629652 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.035573997,
#  'Loss/localization_loss': 0.01327979,
#  'Loss/regularization_loss': 0.115305215,
#  'Loss/total_loss': 0.164159,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.186s
# I0620 01:18:28.267969 140135427274560 model_lib_v2.py:705] Step 5500 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.053957902,
#  'Loss/localization_loss': 0.00976412,
#  'Loss/regularization_loss': 0.1146663,
#  'Loss/total_loss': 0.17838833,
#  'learning_rate': 0.078346714}
# I0620 01:18:28.268563 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.053957902,
#  'Loss/localization_loss': 0.00976412,
#  'Loss/regularization_loss': 0.1146663,
#  'Loss/total_loss': 0.17838833,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.187s
# I0620 01:18:46.954568 140135427274560 model_lib_v2.py:705] Step 5600 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.034964915,
#  'Loss/localization_loss': 0.009349662,
#  'Loss/regularization_loss': 0.11401684,
#  'Loss/total_loss': 0.15833142,
#  'learning_rate': 0.07827295}
# I0620 01:18:46.955101 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.034964915,
#  'Loss/localization_loss': 0.009349662,
#  'Loss/regularization_loss': 0.11401684,
#  'Loss/total_loss': 0.15833142,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.186s
# I0620 01:19:05.514541 140135427274560 model_lib_v2.py:705] Step 5700 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.044637468,
#  'Loss/localization_loss': 0.014963483,
#  'Loss/regularization_loss': 0.11337882,
#  'Loss/total_loss': 0.17297977,
#  'learning_rate': 0.07819763}
# I0620 01:19:05.515073 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.044637468,
#  'Loss/localization_loss': 0.014963483,
#  'Loss/regularization_loss': 0.11337882,
#  'Loss/total_loss': 0.17297977,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.188s
# I0620 01:19:24.280139 140135427274560 model_lib_v2.py:705] Step 5800 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.040408634,
#  'Loss/localization_loss': 0.007351795,
#  'Loss/regularization_loss': 0.112744495,
#  'Loss/total_loss': 0.16050492,
#  'learning_rate': 0.07812072}
# I0620 01:19:24.280706 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.040408634,
#  'Loss/localization_loss': 0.007351795,
#  'Loss/regularization_loss': 0.112744495,
#  'Loss/total_loss': 0.16050492,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.189s
# I0620 01:19:43.182509 140135427274560 model_lib_v2.py:705] Step 5900 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.037657987,
#  'Loss/localization_loss': 0.009501229,
#  'Loss/regularization_loss': 0.1121186,
#  'Loss/total_loss': 0.15927783,
#  'learning_rate': 0.078042254}
# I0620 01:19:43.183341 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.037657987,
# ...
# I0620 01:24:06.537749 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.038411967,
#  'Loss/localization_loss': 0.0072875232,
#  'Loss/regularization_loss': 0.10375118,
#  'Loss/total_loss': 0.14945067,
#  'learning_rate': 0.07678111}
# INFO:tensorflow:Step 7400 per-step time 0.186s
# I0620 01:24:25.147541 140135427274560 model_lib_v2.py:705] Step 7400 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.03929109,
#  'Loss/localization_loss': 0.0072012004,
#  'Loss/regularization_loss': 0.10317844,
#  'Loss/total_loss': 0.14967074,
#  'learning_rate': 0.076679565}
# I0620 01:24:25.148122 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03929109,
#  'Loss/localization_loss': 0.0072012004,
#  'Loss/regularization_loss': 0.10317844,
#  'Loss/total_loss': 0.14967074,
#  'learning_rate': 0.076679565}
# INFO:tensorflow:Step 7500 per-step time 0.187s
# I0620 01:24:43.829440 140135427274560 model_lib_v2.py:705] Step 7500 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.032030817,
#  'Loss/localization_loss': 0.0089657,
#  'Loss/regularization_loss': 0.10261725,
#  'Loss/total_loss': 0.14361377,
#  'learning_rate': 0.0765765}
# I0620 01:24:43.829994 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.032030817,
#  'Loss/localization_loss': 0.0089657,
#  'Loss/regularization_loss': 0.10261725,
#  'Loss/total_loss': 0.14361377,
#  'learning_rate': 0.0765765}
# INFO:tensorflow:Step 7600 per-step time 0.188s
# I0620 01:25:02.653759 140135427274560 model_lib_v2.py:705] Step 7600 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.03856879,
#  'Loss/localization_loss': 0.0074236593,
#  'Loss/regularization_loss': 0.10206041,
#  'Loss/total_loss': 0.14805286,
#  'learning_rate': 0.07647194}
# I0620 01:25:02.654579 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03856879,
#  'Loss/localization_loss': 0.0074236593,
#  'Loss/regularization_loss': 0.10206041,
#  'Loss/total_loss': 0.14805286,
#  'learning_rate': 0.07647194}
# INFO:tensorflow:Step 7700 per-step time 0.188s
# I0620 01:25:21.473383 140135427274560 model_lib_v2.py:705] Step 7700 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.030586129,
#  'Loss/localization_loss': 0.0072672665,
#  'Loss/regularization_loss': 0.10151365,
#  'Loss/total_loss': 0.13936704,
#  'learning_rate': 0.07636588}
# I0620 01:25:21.474396 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.030586129,
#  'Loss/localization_loss': 0.0072672665,
#  'Loss/regularization_loss': 0.10151365,
#  'Loss/total_loss': 0.13936704,
#  'learning_rate': 0.07636588}
# INFO:tensorflow:Step 7800 per-step time 0.187s
# I0620 01:25:40.219034 140135427274560 model_lib_v2.py:705] Step 7800 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.037894126,
#  'Loss/localization_loss': 0.008809462,
#  'Loss/regularization_loss': 0.10096372,
#  'Loss/total_loss': 0.1476673,
#  'learning_rate': 0.07625833}
# I0620 01:25:40.219716 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.037894126,
#  'Loss/localization_loss': 0.008809462,
#  'Loss/regularization_loss': 0.10096372,
#  'Loss/total_loss': 0.1476673,
#  'learning_rate': 0.07625833}
# INFO:tensorflow:Step 7900 per-step time 0.186s
# I0620 01:25:58.858760 140135427274560 model_lib_v2.py:705] Step 7900 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.035103038,
#  'Loss/localization_loss': 0.00738316,
#  'Loss/regularization_loss': 0.10042319,
#  'Loss/total_loss': 0.14290938,
#  'learning_rate': 0.07614928}
# I0620 01:25:58.859474 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.035103038,
#  'Loss/localization_loss': 0.00738316,
#  'Loss/regularization_loss': 0.10042319,
#  'Loss/total_loss': 0.14290938,
#  'learning_rate': 0.07614928}
# INFO:tensorflow:Step 8000 per-step time 0.187s
# I0620 01:26:17.510630 140135427274560 model_lib_v2.py:705] Step 8000 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.033079967,
#  'Loss/localization_loss': 0.00752371,
#  'Loss/regularization_loss': 0.0998843,
#  'Loss/total_loss': 0.14048797,
#  'learning_rate': 0.07603875}
# I0620 01:26:17.511204 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.033079967,
#  'Loss/localization_loss': 0.00752371,
#  'Loss/regularization_loss': 0.0998843,
#  'Loss/total_loss': 0.14048797,
#  'learning_rate': 0.07603875}
# INFO:tensorflow:Step 8100 per-step time 0.193s
# I0620 01:26:36.814478 140135427274560 model_lib_v2.py:705] Step 8100 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.029004654,
#  'Loss/localization_loss': 0.0077985288,
#  'Loss/regularization_loss': 0.09934416,
#  'Loss/total_loss': 0.13614734,
#  'learning_rate': 0.07592674}
# I0620 01:26:36.815151 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.029004654,
#  'Loss/localization_loss': 0.0077985288,
#  'Loss/regularization_loss': 0.09934416,
#  'Loss/total_loss': 0.13614734,
#  'learning_rate': 0.07592674}
# INFO:tensorflow:Step 8200 per-step time 0.186s
# I0620 01:26:55.440299 140135427274560 model_lib_v2.py:705] Step 8200 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.029564755,
#  'Loss/localization_loss': 0.0076410775,
#  'Loss/regularization_loss': 0.0988059,
#  'Loss/total_loss': 0.13601173,
#  'learning_rate': 0.075813256}
# I0620 01:26:55.440847 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.029564755,
#  'Loss/localization_loss': 0.0076410775,
#  'Loss/regularization_loss': 0.0988059,
#  'Loss/total_loss': 0.13601173,
#  'learning_rate': 0.075813256}
# INFO:tensorflow:Step 8300 per-step time 0.186s
# I0620 01:27:14.065750 140135427274560 model_lib_v2.py:705] Step 8300 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.040264282,
#  'Loss/localization_loss': 0.008805974,
#  'Loss/regularization_loss': 0.09827628,
#  'Loss/total_loss': 0.14734654,
#  'learning_rate': 0.07569829}
# I0620 01:27:14.066294 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.040264282,
#  'Loss/localization_loss': 0.008805974,
#  'Loss/regularization_loss': 0.09827628,
#  'Loss/total_loss': 0.14734654,
#  'learning_rate': 0.07569829}
# INFO:tensorflow:Step 8400 per-step time 0.188s
# I0620 01:27:32.827643 140135427274560 model_lib_v2.py:705] Step 8400 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.034862842,
#  'Loss/localization_loss': 0.0059749237,
#  'Loss/regularization_loss': 0.09774628,
#  'Loss/total_loss': 0.13858405,
#  'learning_rate': 0.07558186}
# I0620 01:27:32.828265 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.034862842,
#  'Loss/localization_loss': 0.0059749237,
#  'Loss/regularization_loss': 0.09774628,
#  'Loss/total_loss': 0.13858405,
#  'learning_rate': 0.07558186}
# INFO:tensorflow:Step 8500 per-step time 0.188s
# I0620 01:27:51.641406 140135427274560 model_lib_v2.py:705] Step 8500 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.029321142,
#  'Loss/localization_loss': 0.007552762,
#  'Loss/regularization_loss': 0.09723162,
#  'Loss/total_loss': 0.13410552,
#  'learning_rate': 0.07546397}
# I0620 01:27:51.642215 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.029321142,
#  'Loss/localization_loss': 0.007552762,
#  'Loss/regularization_loss': 0.09723162,
#  'Loss/total_loss': 0.13410552,
#  'learning_rate': 0.07546397}
# INFO:tensorflow:Step 8600 per-step time 0.189s
# I0620 01:28:10.545226 140135427274560 model_lib_v2.py:705] Step 8600 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.03478866,
#  'Loss/localization_loss': 0.01182464,
#  'Loss/regularization_loss': 0.09672864,
#  'Loss/total_loss': 0.14334194,
#  'learning_rate': 0.075344615}
# I0620 01:28:10.545793 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03478866,
#  'Loss/localization_loss': 0.01182464,
#  'Loss/regularization_loss': 0.09672864,
#  'Loss/total_loss': 0.14334194,
#  'learning_rate': 0.075344615}
# INFO:tensorflow:Step 8700 per-step time 0.188s
# I0620 01:28:29.352096 140135427274560 model_lib_v2.py:705] Step 8700 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.033049982,
#  'Loss/localization_loss': 0.0074494844,
#  'Loss/regularization_loss': 0.09622651,
#  'Loss/total_loss': 0.13672598,
#  'learning_rate': 0.07522382}
# I0620 01:28:29.352661 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.033049982,
#  'Loss/localization_loss': 0.0074494844,
#  'Loss/regularization_loss': 0.09622651,
#  'Loss/total_loss': 0.13672598,
#  'learning_rate': 0.07522382}
# INFO:tensorflow:Step 8800 per-step time 0.187s
# I0620 01:28:48.035545 140135427274560 model_lib_v2.py:705] Step 8800 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.033323925,
#  'Loss/localization_loss': 0.0076307007,
#  'Loss/regularization_loss': 0.09572911,
#  'Loss/total_loss': 0.13668373,
#  'learning_rate': 0.07510157}
# I0620 01:28:48.036272 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.033323925,
#  'Loss/localization_loss': 0.0076307007,
#  'Loss/regularization_loss': 0.09572911,
#  'Loss/total_loss': 0.13668373,
#  'learning_rate': 0.07510157}
# INFO:tensorflow:Step 8900 per-step time 0.187s
# I0620 01:29:06.731614 140135427274560 model_lib_v2.py:705] Step 8900 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.03222978,
#  'Loss/localization_loss': 0.0075742835,
#  'Loss/regularization_loss': 0.095220774,
#  'Loss/total_loss': 0.13502485,
#  'learning_rate': 0.074977875}
# I0620 01:29:06.732199 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03222978,
#  'Loss/localization_loss': 0.0075742835,
#  'Loss/regularization_loss': 0.095220774,
#  'Loss/total_loss': 0.13502485,
#  'learning_rate': 0.074977875}
# INFO:tensorflow:Step 9000 per-step time 0.186s
# I0620 01:29:25.332878 140135427274560 model_lib_v2.py:705] Step 9000 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.033017702,
#  'Loss/localization_loss': 0.008419031,
#  'Loss/regularization_loss': 0.09471363,
#  'Loss/total_loss': 0.13615036,
#  'learning_rate': 0.07485275}
# I0620 01:29:25.333451 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.033017702,
#  'Loss/localization_loss': 0.008419031,
#  'Loss/regularization_loss': 0.09471363,
#  'Loss/total_loss': 0.13615036,
#  'learning_rate': 0.07485275}
# INFO:tensorflow:Step 9100 per-step time 0.191s
# I0620 01:29:44.410894 140135427274560 model_lib_v2.py:705] Step 9100 per-step time 0.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.03570218,
#  'Loss/localization_loss': 0.0065610674,
#  'Loss/regularization_loss': 0.094212815,
#  'Loss/total_loss': 0.13647607,
#  'learning_rate': 0.07472619}
# I0620 01:29:44.411430 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03570218,
#  'Loss/localization_loss': 0.0065610674,
#  'Loss/regularization_loss': 0.094212815,
#  'Loss/total_loss': 0.13647607,
#  'learning_rate': 0.07472619}
# INFO:tensorflow:Step 9200 per-step time 0.187s
# I0620 01:30:03.143984 140135427274560 model_lib_v2.py:705] Step 9200 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.028301664,
#  'Loss/localization_loss': 0.010590672,
#  'Loss/regularization_loss': 0.09371754,
#  'Loss/total_loss': 0.13260987,
#  'learning_rate': 0.07459819}
# I0620 01:30:03.144550 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.028301664,
#  'Loss/localization_loss': 0.010590672,
#  'Loss/regularization_loss': 0.09371754,
#  'Loss/total_loss': 0.13260987,
#  'learning_rate': 0.07459819}
# INFO:tensorflow:Step 9300 per-step time 0.186s
# I0620 01:30:21.737226 140135427274560 model_lib_v2.py:705] Step 9300 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.031595387,
#  'Loss/localization_loss': 0.007609733,
#  'Loss/regularization_loss': 0.0932176,
#  'Loss/total_loss': 0.13242272,
#  'learning_rate': 0.074468784}
# I0620 01:30:21.737748 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.031595387,
#  'Loss/localization_loss': 0.007609733,
#  'Loss/regularization_loss': 0.0932176,
#  'Loss/total_loss': 0.13242272,
#  'learning_rate': 0.074468784}
# INFO:tensorflow:Step 9400 per-step time 0.188s
# I0620 01:30:40.553097 140135427274560 model_lib_v2.py:705] Step 9400 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.031305004,
#  'Loss/localization_loss': 0.0069234166,
#  'Loss/regularization_loss': 0.09274084,
#  'Loss/total_loss': 0.13096926,
#  'learning_rate': 0.074337944}
# I0620 01:30:40.553697 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.031305004,
#  'Loss/localization_loss': 0.0069234166,
#  'Loss/regularization_loss': 0.09274084,
#  'Loss/total_loss': 0.13096926,
#  'learning_rate': 0.074337944}
# INFO:tensorflow:Step 9500 per-step time 0.188s
# I0620 01:30:59.336594 140135427274560 model_lib_v2.py:705] Step 9500 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.037018552,
#  'Loss/localization_loss': 0.007298283,
#  'Loss/regularization_loss': 0.092268206,
#  'Loss/total_loss': 0.13658504,
#  'learning_rate': 0.074205704}
# I0620 01:30:59.337706 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.037018552,
#  'Loss/localization_loss': 0.007298283,
#  'Loss/regularization_loss': 0.092268206,
#  'Loss/total_loss': 0.13658504,
#  'learning_rate': 0.074205704}
# INFO:tensorflow:Step 9600 per-step time 0.185s
# I0620 01:31:17.827047 140135427274560 model_lib_v2.py:705] Step 9600 per-step time 0.185s
# INFO:tensorflow:{'Loss/classification_loss': 0.03648494,
#  'Loss/localization_loss': 0.006307758,
#  'Loss/regularization_loss': 0.09178688,
#  'Loss/total_loss': 0.13457957,
#  'learning_rate': 0.07407206}
# I0620 01:31:17.827573 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.03648494,
#  'Loss/localization_loss': 0.006307758,
#  'Loss/regularization_loss': 0.09178688,
#  'Loss/total_loss': 0.13457957,
#  'learning_rate': 0.07407206}
# INFO:tensorflow:Step 9700 per-step time 0.184s
# I0620 01:31:36.226780 140135427274560 model_lib_v2.py:705] Step 9700 per-step time 0.184s
# INFO:tensorflow:{'Loss/classification_loss': 0.034488123,
#  'Loss/localization_loss': 0.007855857,
#  'Loss/regularization_loss': 0.09130935,
#  'Loss/total_loss': 0.13365334,
#  'learning_rate': 0.073937014}
# I0620 01:31:36.227342 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.034488123,
#  'Loss/localization_loss': 0.007855857,
#  'Loss/regularization_loss': 0.09130935,
#  'Loss/total_loss': 0.13365334,
#  'learning_rate': 0.073937014}
# INFO:tensorflow:Step 9800 per-step time 0.186s
# I0620 01:31:54.842668 140135427274560 model_lib_v2.py:705] Step 9800 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.02935556,
#  'Loss/localization_loss': 0.0062904595,
#  'Loss/regularization_loss': 0.090832144,
#  'Loss/total_loss': 0.12647817,
#  'learning_rate': 0.07380057}
# I0620 01:31:54.843189 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.02935556,
#  'Loss/localization_loss': 0.0062904595,
#  'Loss/regularization_loss': 0.090832144,
#  'Loss/total_loss': 0.12647817,
#  'learning_rate': 0.07380057}
# INFO:tensorflow:Step 9900 per-step time 0.187s
# I0620 01:32:13.587865 140135427274560 model_lib_v2.py:705] Step 9900 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.036869142,
#  'Loss/localization_loss': 0.008869453,
#  'Loss/regularization_loss': 0.09035615,
#  'Loss/total_loss': 0.13609475,
#  'learning_rate': 0.073662736}
# I0620 01:32:13.588429 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.036869142,
#  'Loss/localization_loss': 0.008869453,
#  'Loss/regularization_loss': 0.09035615,
#  'Loss/total_loss': 0.13609475,
#  'learning_rate': 0.073662736}
# INFO:tensorflow:Step 10000 per-step time 0.187s
# I0620 01:32:32.327644 140135427274560 model_lib_v2.py:705] Step 10000 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.030044237,
#  'Loss/localization_loss': 0.007851035,
#  'Loss/regularization_loss': 0.08990755,
#  'Loss/total_loss': 0.12780282,
#  'learning_rate': 0.07352352}
# I0620 01:32:32.328188 140135427274560 model_lib_v2.py:708] {'Loss/classification_loss': 0.030044237,
#  'Loss/localization_loss': 0.007851035,
#  'Loss/regularization_loss': 0.08990755,
#  'Loss/total_loss': 0.12780282,
#  'learning_rate': 0.07352352}

# %%
# Make a directory to store the trained TFLite model
# !mkdir /home/thuannd/SSD/custom_model_lite
output_directory = '/home/thuannd/SSD/custom_model_lite'

# Path to training directory (the conversion script automatically chooses the highest checkpoint file)
last_model_path = '/home/thuannd/SSD/training'

# !python /home/thuannd/SSD/models/research/object_detection/export_tflite_graph_tf2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/thuannd/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# I0620 03:27:38.011067 139882395174720 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0620 03:27:42.748522 139882395174720 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-20 03:27:44.428823: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# I0620 03:27:44.989629 139882395174720 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f37cf87fb20>, because it is not built.
# W0620 03:27:46.165419 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f37cf87fb20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f37cf5ff910>, because it is not built.
# W0620 03:27:46.390081 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f37cf5ff910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac552250>, because it is not built.
# W0620 03:27:46.390255 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac552250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37c7381850>, because it is not built.
# W0620 03:27:46.390339 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37c7381850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f37c7381370>, because it is not built.
# W0620 03:27:46.390409 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f37c7381370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37c7381940>, because it is not built.
# W0620 03:27:46.390474 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37c7381940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37affe9d90>, because it is not built.
# W0620 03:27:46.390538 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37affe9d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f37affe9a00>, because it is not built.
# W0620 03:27:46.390600 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f37affe9a00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37affe90d0>, because it is not built.
# W0620 03:27:46.390662 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37affe90d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37affe9640>, because it is not built.
# W0620 03:27:46.390724 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37affe9640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f37ac4a3af0>, because it is not built.
# W0620 03:27:46.390801 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f37ac4a3af0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac4a3880>, because it is not built.
# W0620 03:27:46.390867 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac4a3880>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac4a34f0>, because it is not built.
# W0620 03:27:46.390934 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac4a34f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37cf5ffee0>, because it is not built.
# W0620 03:27:46.390999 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37cf5ffee0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37aff6b7f0>, because it is not built.
# W0620 03:27:46.391065 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37aff6b7f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac4e4ac0>, because it is not built.
# W0620 03:27:46.391130 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac4e4ac0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac4e42b0>, because it is not built.
# W0620 03:27:46.391195 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac4e42b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac4e4c70>, because it is not built.
# W0620 03:27:46.391260 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac4e4c70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac4e4610>, because it is not built.
# W0620 03:27:46.391325 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac4e4610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2da730>, because it is not built.
# W0620 03:27:46.391390 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2da730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2da5b0>, because it is not built.
# W0620 03:27:46.391462 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2da5b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37cf5fff10>, because it is not built.
# W0620 03:27:46.391528 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37cf5fff10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac5403d0>, because it is not built.
# W0620 03:27:46.391593 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac5403d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac50a6d0>, because it is not built.
# W0620 03:27:46.391658 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac50a6d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac50a970>, because it is not built.
# W0620 03:27:46.391729 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac50a970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37c73b6640>, because it is not built.
# W0620 03:27:46.391796 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37c73b6640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37c73b6850>, because it is not built.
# W0620 03:27:46.391862 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37c73b6850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37c73f9eb0>, because it is not built.
# W0620 03:27:46.391927 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37c73f9eb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37c73f9d00>, because it is not built.
# W0620 03:27:46.391992 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37c73f9d00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37cf5fff40>, because it is not built.
# W0620 03:27:46.392065 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37cf5fff40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2c65b0>, because it is not built.
# W0620 03:27:46.392132 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2c65b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2ce7c0>, because it is not built.
# W0620 03:27:46.392196 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2ce7c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2ce490>, because it is not built.
# W0620 03:27:46.392262 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2ce490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2ce130>, because it is not built.
# W0620 03:27:46.392327 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2ce130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2ce250>, because it is not built.
# W0620 03:27:46.392393 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2ce250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2ceb50>, because it is not built.
# W0620 03:27:46.392458 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2ceb50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2cebe0>, because it is not built.
# W0620 03:27:46.392529 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2cebe0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2d7850>, because it is not built.
# W0620 03:27:46.392597 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac2d7850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2d7f40>, because it is not built.
# W0620 03:27:46.392663 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac2d7f40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac33bd00>, because it is not built.
# W0620 03:27:46.392741 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac33bd00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac33b3d0>, because it is not built.
# W0620 03:27:46.392808 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac33b3d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac33b700>, because it is not built.
# W0620 03:27:46.392876 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac33b700>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac5042e0>, because it is not built.
# W0620 03:27:46.392943 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37ac5042e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac40dee0>, because it is not built.
# W0620 03:27:46.393010 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f37ac40dee0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37c73b82e0>, because it is not built.
# W0620 03:27:46.393078 139882395174720 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f37c73b82e0>, because it is not built.
# W0620 03:28:01.299673 139882395174720 save.py:260] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 104). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/thuannd/SSD/custom_model_lite/saved_model/assets
# I0620 03:28:06.186190 139882395174720 builder_impl.py:779] Assets written to: /home/thuannd/SSD/custom_model_lite/saved_model/assets

# %%
# Convert exported graph file into TFLite model file
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model('/home/thuannd/SSD/custom_model_lite/saved_model')
tflite_model = converter.convert()

with open('/home/thuannd/SSD/custom_model_lite/detect.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# 2023-06-20 03:28:40.338966: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2023-06-20 03:28:40.339016: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.

# %%
# Script to run custom TFLite model on test images to detect objects
# Source: https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/TFLite_detection_image.py

# Import packages
import os
import cv2
import numpy as np
import sys
import glob
import random
import importlib.util
from tensorflow.lite.python.interpreter import Interpreter

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

### Define function for inferencing with TFLite model and displaying results

def tflite_detect_images(modelpath, imgpath, lblpath, min_conf=0.5, num_test_images=10, savepath='/home/thuannd/SSD/results', txt_only=False):

  # Grab filenames of all images in test folder
  images = glob.glob(imgpath + '/*.jpg') + glob.glob(imgpath + '/*.JPG') + glob.glob(imgpath + '/*.png') + glob.glob(imgpath + '/*.bmp')

  # Load the label map into memory
  with open(lblpath, 'r') as f:
      labels = [line.strip() for line in f.readlines()]

  # Load the Tensorflow Lite model into memory
  interpreter = Interpreter(model_path=modelpath)
  interpreter.allocate_tensors()

  # Get model details
  input_details = interpreter.get_input_details()
  output_details = interpreter.get_output_details()
  height = input_details[0]['shape'][1]
  width = input_details[0]['shape'][2]

  float_input = (input_details[0]['dtype'] == np.float32)

  input_mean = 127.5
  input_std = 127.5

  # Randomly select test images
  images_to_test = random.sample(images, num_test_images)

  # Loop over every image and perform detection
  for image_path in images_to_test:

      # Load image and resize to expected shape [1xHxWx3]
      image = cv2.imread(image_path)
      image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
      imH, imW, _ = image.shape 
      image_resized = cv2.resize(image_rgb, (width, height))
      input_data = np.expand_dims(image_resized, axis=0)

      # Normalize pixel values if using a floating model (i.e. if model is non-quantized)
      if float_input:
          input_data = (np.float32(input_data) - input_mean) / input_std

      # Perform the actual detection by running the model with the image as input
      interpreter.set_tensor(input_details[0]['index'],input_data)
      interpreter.invoke()

      # Retrieve detection results
      boxes = interpreter.get_tensor(output_details[1]['index'])[0] # Bounding box coordinates of detected objects
      classes = interpreter.get_tensor(output_details[3]['index'])[0] # Class index of detected objects
      scores = interpreter.get_tensor(output_details[0]['index'])[0] # Confidence of detected objects

      detections = []

      # Loop over all detections and draw detection box if confidence is above minimum threshold
      for i in range(len(scores)):
          if ((scores[i] > min_conf) and (scores[i] <= 1.0)):

              # Get bounding box coordinates and draw box
              # Interpreter can return coordinates that are outside of image dimensions, need to force them to be within image using max() and min()
              ymin = int(max(1,(boxes[i][0] * imH)))
              xmin = int(max(1,(boxes[i][1] * imW)))
              ymax = int(min(imH,(boxes[i][2] * imH)))
              xmax = int(min(imW,(boxes[i][3] * imW)))
              
              cv2.rectangle(image, (xmin,ymin), (xmax,ymax), (10, 255, 0), 2)

              # Draw label
              object_name = labels[int(classes[i])] # Look up object name from "labels" array using class index
              label = '%s: %d%%' % (object_name, int(scores[i]*100)) # Example: 'person: 72%'
              labelSize, baseLine = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2) # Get font size
              label_ymin = max(ymin, labelSize[1] + 10) # Make sure not to draw label too close to top of window
              cv2.rectangle(image, (xmin, label_ymin-labelSize[1]-10), (xmin+labelSize[0], label_ymin+baseLine-10), (255, 255, 255), cv2.FILLED) # Draw white box to put label text in
              cv2.putText(image, label, (xmin, label_ymin-7), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2) # Draw label text

              detections.append([object_name, scores[i], xmin, ymin, xmax, ymax])

      
      # All the results have been drawn on the image, now display the image
      if txt_only == False: # "text_only" controls whether we want to display the image results or just save them in .txt files
        image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(12,16))
        plt.imshow(image)
        plt.show()
      
      # Save detection results in .txt files (for calculating mAP)
      elif txt_only == True:

        # Get filenames and paths
        image_fn = os.path.basename(image_path)      
        base_fn, ext = os.path.splitext(image_fn)
        txt_result_fn = base_fn +'.txt'
        txt_savepath = os.path.join(savepath, txt_result_fn)

        # Write results to text file
        # (Using format defined by https://github.com/Cartucho/mAP, which will make it easy to calculate mAP)
        with open(txt_savepath,'w') as f:
            for detection in detections:
                f.write('%s %.4f %d %d %d %d\n' % (detection[0], detection[1], detection[2], detection[3], detection[4], detection[5]))

  return

# %%
# %cd /home/thuannd/SSD/images/test
# !wget https://www.cleanipedia.com/images/5iwkm8ckyw6v/27MHAUsq2aNgUi0cOGCw6S/ea072e08b6cd26b4c0e0db9f2cfd4c3a/a2h1LW11aS1ob2ktcGhvbmcta2luLTIuanBn/990w-660h/c%C3%A1ch-kh%E1%BB%AD-m%C3%B9i%2C-l%C3%A0m-th%C6%A1m-ph%C3%B2ng-b%E1%BA%B1ng-tr%C3%A1i-th%C6%A1m-%C4%91%C6%A1n-gi%E1%BA%A3n.jpg
# Out:
# /home/thuannd/SSD/images/test
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2023-06-20 03:36:01--  https://www.cleanipedia.com/images/5iwkm8ckyw6v/27MHAUsq2aNgUi0cOGCw6S/ea072e08b6cd26b4c0e0db9f2cfd4c3a/a2h1LW11aS1ob2ktcGhvbmcta2luLTIuanBn/990w-660h/c%C3%A1ch-kh%E1%BB%AD-m%C3%B9i%2C-l%C3%A0m-th%C6%A1m-ph%C3%B2ng-b%E1%BA%B1ng-tr%C3%A1i-th%C6%A1m-%C4%91%C6%A1n-gi%E1%BA%A3n.jpg
# Resolving www.cleanipedia.com (www.cleanipedia.com)... 108.157.30.78, 108.157.30.85, 108.157.30.8, ...
# Connecting to www.cleanipedia.com (www.cleanipedia.com)|108.157.30.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89425 (87K) [image/jpeg]
# Saving to: ‘cách-khử-mùi,-làm-thơm-phòng-bằng-trái-thơm-đơn-giản.jpg’
#
# cách-khử-mùi,-làm-t 100%[===================>]  87,33K   324KB/s    in 0,3s
#
# 2023-06-20 03:36:02 (324 KB/s) - ‘cách-khử-mùi,-làm-thơm-phòng-bằng-trái-thơm-đơn-giản.jpg’ saved [89425/89425]

# %%
# Set up variables for running user's model
PATH_TO_IMAGES='/home/thuannd/SSD/images/test'   # Path to test images folder
PATH_TO_MODEL='/home/thuannd/SSD/custom_model_lite/detect.tflite'   # Path to .tflite model file
PATH_TO_LABELS='/home/thuannd/SSD/labelmap.txt'   # Path to labelmap.txt file
min_conf_threshold=0.5   # Confidence threshold (try changing this to 0.01 if you don't see any detection results)
images_to_test = 1   # Number of images to run detection on

# Run inferencing function!
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test)

# %%
# !git clone https://github.com/Cartucho/mAP /home/thuannd/SSD/mAP
# %cd /home/thuannd/SSD/mAP
# !rm input/detection-results/* 
# !rm input/ground-truth/* 
# !rm input/images-optional/* 
# !wget https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/calculate_map_cartucho.py
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Cloning into '/home/thuannd/SSD/mAP'...
# remote: Enumerating objects: 908, done.
# remote: Total 908 (delta 0), reused 0 (delta 0), pack-reused 908
# Receiving objects: 100% (908/908), 14.71 MiB | 3.81 MiB/s, done.
# Resolving deltas: 100% (321/321), done.
# /home/thuannd/SSD/mAP
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2023-06-20 03:46:17--  https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/calculate_map_cartucho.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5397 (5,3K) [text/plain]
# Saving to: ‘calculate_map_cartucho.py’
#
# calculate_map_cartu 100%[===================>]   5,27K  --.-KB/s    in 0,001s
#
# 2023-06-20 03:46:18 (8,48 MB/s) - ‘calculate_map_cartucho.py’ saved [5397/5397]

# %%
# !cp /home/thuannd/SSD/images/train/* /home/thuannd/SSD/mAP/input/images-optional # Copy images and xml files
# !mv /home/thuannd/SSD/mAP/input/images-optional/*.xml /home/thuannd/SSD/mAP/input/ground-truth/  # Move xml files to the appropriate folder
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !python /home/thuannd/SSD/mAP/scripts/extra/convert_gt_xml.py
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Conversion completed!

# %%
# Set up variables for running inference, this time to get detection results saved as .txt files
PATH_TO_IMAGES='/home/thuannd/SSD/images/train'   # Path to test images folder
PATH_TO_MODEL='/home/thuannd/SSD/custom_model_lite/detect.tflite'   # Path to .tflite model file
PATH_TO_LABELS='/home/thuannd/SSD/labelmap.txt'   # Path to labelmap.txt file
PATH_TO_RESULTS='/home/thuannd/SSD/mAP/input/detection-results' # Folder to save detection results in
min_conf_threshold=0.1   # Confidence threshold

# Use all the images in the test folder
image_list = glob.glob(PATH_TO_IMAGES + '/*.jpg') + glob.glob(PATH_TO_IMAGES + '/*.JPG') + glob.glob(PATH_TO_IMAGES + '/*.png') + glob.glob(PATH_TO_IMAGES + '/*.bmp')
images_to_test = min(500, len(image_list)) # If there are more than 500 images in the folder, just use 500

# Tell function to just save results and not display images
txt_only = True

# Run inferencing function!
print('Starting inference on %d images...' % images_to_test)
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test, PATH_TO_RESULTS, txt_only)
print('Finished inferencing!')
# Out:
# Starting inference on 200 images...
# Finished inferencing!

# %%
# %cd /home/thuannd/SSD/mAP
# !python calc.py --labels=/home/thuannd/SSD/labelmap.txt
# Out:
# /home/thuannd/SSD/mAP
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Calculating mAP and Precision at 0.50 IoU threshold...
# 100.00% = BananaFresh AP
# 100.00% = DragonFruitFresh AP
# 100.00% = PineAppleFresh AP
# 100.00% = SnakeFruitFresh AP
# mAP = 100.00%
# Traceback (most recent call last):
#   File "/home/thuannd/SSD/mAP/calc.py", line 102, in <module>
#     mAP_results[class_name][i] = class_mAP
# KeyError: 'BananaFresh'

# %%
import matplotlib.pyplot as plt

# Tạo danh sách các lớp và dữ liệu precision/recall tương ứng
classes = ["BananaFresh", "DragonFruitFresh", "PineAppleFresh", "SnakeFruitFresh"]
precision = [
    [1.00, 1.00, 1.00, ...],  # Precision cho BananaFresh
    [1.00, 1.00, 1.00, ...],  # Precision cho DragonFruitFresh
    [1.00, 1.00, 1.00, ...]   # Precision cho PineAppleFresh
]
recall = [
    [0.01, 0.02, 0.03, ...],  # Recall cho BananaFresh
    [0.01, 0.02, 0.03, ...],  # Recall cho DragonFruitFresh
    [0.01, 0.02, 0.03, ...]   # Recall cho PineAppleFresh
]

# Vẽ đồ thị precision
plt.figure(figsize=(10, 6))
for i in range(len(classes)):
    plt.plot(recall[i], precision[i], marker='o', label=classes[i])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 19
#      17 plt.figure(figsize=(10, 6))
#      18 for i in range(len(classes)):
# ---> 19     plt.plot(recall[i], precision[i], marker='o', label=classes[i])
#      20 plt.xlabel('Recall')
#      21 plt.ylabel('Precision')
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/axes/_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/axes/_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/lines.py:1029, in Line2D.get_path(self)
#    1027 """Return the `~matplotlib.path.Path` associated with this line."""
#    1028 if self._invalidy or self._invalidx:
# -> 1029     self.recache()
#    1030 return self._path
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/lines.py:657, in Line2D.recache(self, always)
#     655 if always or self._invalidx:
#     656     xconv = self.convert_xunits(self._xorig)
# --> 657     x = _to_unmasked_float_array(xconv).ravel()
#     658 else:
#     659     x = self._x
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1335, in _to_unmasked_float_array(x)
#    1333     return np.ma.asarray(x, float).filled(np.nan)
#    1334 else:
# -> 1335     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a number, not 'ellipsis'

# %%
import os
import re

folder_path = "/home/thuannd/SSD/mAP/input/ground-truth"

# Lặp qua tất cả các file trong thư mục ground-truth
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        # Đọc nội dung của file
        with open(file_path, 'r') as f:
            lines = f.readlines()

        # Xử lý nội dung của file
        processed_lines = []
        for line in lines:
            # Thay đổi các trường hợp tên
            line = re.sub(r"\bbanana\b", "BananaFresh", line)
            line = re.sub(r"\bsnakefruit\b", "SnakeFruitFresh", line)
            line = re.sub(r"\bpineapple\b", "PineAppleFresh", line)
            line = re.sub(r"\bdragonfruit\b", "DragonFruitFresh", line)

            processed_lines.append(line)

        # Ghi nội dung đã được xử lý vào file
        with open(file_path, 'w') as f:
            f.writelines(processed_lines)

print("Hoàn thành việc thay đổi nội dung trong tất cả các file trong thư mục ground-truth.")
# Out:
# Hoàn thành việc thay đổi nội dung trong tất cả các file trong thư mục ground-truth.

# %%
# Move labelmap and pipeline config files into TFLite model folder and zip it up
# !cp /home/thuannd/SSD/labelmap.txt /home/thuannd/SSD/custom_model_lite
# !cp /home/thuannd/SSD/labelmap.pbtxt /home/thuannd/SSD/custom_model_lite
# !cp /home/thuannd/SSD/models/mymodel/pipeline_file.config /home/thuannd/SSD/custom_model_lite

# %cd /home/thuannd/SSD
# !zip -r custom_model_lite.zip custom_model_lite
# Out:
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /home/thuannd/SSD
# /bin/bash: /home/thuannd/miniconda3/envs/huynhhoa/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#   adding: custom_model_lite/ (stored 0%)
#   adding: custom_model_lite/pipeline_file.config (deflated 65%)
#   adding: custom_model_lite/labelmap.pbtxt (deflated 52%)
#   adding: custom_model_lite/labelmap.txt (deflated 27%)
#   adding: custom_model_lite/detect.tflite (deflated 9%)
#   adding: custom_model_lite/saved_model/ (stored 0%)
#   adding: custom_model_lite/saved_model/saved_model.pb (deflated 91%)
#   adding: custom_model_lite/saved_model/assets/ (stored 0%)
#   adding: custom_model_lite/saved_model/variables/ (stored 0%)
#   adding: custom_model_lite/saved_model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: custom_model_lite/saved_model/variables/variables.index (deflated 78%)

# %%
from google.colab import files

files.download('/content/custom_model_lite.zip')
